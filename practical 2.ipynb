# %% [markdown]
# # Practical 11

# %%
# Pandas series anddataframe Operation
# !pip install pandas
import pandas as pd

#----------------SERIES------------

#Creating a series
series1 =pd.Series([10,20,30,40,50])

print("Pandas Series:")
print(series1)

# Accessing Series Elements
print(series1[0])

# Series with Custom Index
series2 = pd.Series(
    [85,50,95],
    index=["Math","Science","English"]
)

print("\nSeries with Custom Index:")
print(series2)

#----------------DATAFRAME------------
# Out:
# Requirement already satisfied: pandas in C:\Users\Admin\AppData\Local\anaconda3\Lib\site-packages (3.0.3)
# Requirement already satisfied: numpy>=2.3.3 in C:\Users\Admin\AppData\Local\anaconda3\Lib\site-packages (from pandas) (2.4.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in C:\Users\Admin\AppData\Local\anaconda3\Lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in C:\Users\Admin\AppData\Local\anaconda3\Lib\site-packages (from pandas) (2026.2)
# Requirement already satisfied: six>=1.5 in C:\Users\Admin\AppData\Local\anaconda3\Lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Pandas Series:
# 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
# 10
#
# Series with Custom Index:
# Math       85
# Science    50
# English    95
# dtype: int64

# %% [markdown]
# # practical 12

# %%
import pandas as pd
series1=pd.Series([10,20,30,40,50])
print("Pandas series:",series1)
print("\nFirst Element:",series1[0])
series2=pd.Series([80,90,95],index=["math","science","english"])
print("\nSeries With custom index:",series2)
student={"id":[101,102,103],"name":["sakshi","rahul","ankit"],"marks":[95,88,90]}
df=pd.DataFrame(student)
print("\nDataFrame:")
print(df)
print("\nFirst two rows:",df.head(2))
print("\nlast two rows:",df.tail(2))
print("\ncolumn names:",df.columns)

# Accessing Rows using iloc
print("\nSecond Row using iloc:")
print(df.iloc[0]) # work on index

# Adding New Column
df["Grade"]=["A","B","A"]

print("\nAfter Adding Grade column:")
print(df)

# Updating Values
df.loc[1,"Marks"]=92

print("\nAfter Updating Marks:")
print(df)

# Deleting Column
df.drop("Grade", axis=1, inplace=True)

print("\nAfter Removing Grade column:")
print(df)

# Dataframe Information
print("\nDataFrame Information:")
print(df.info())

# Statistical Summary
print("\nStatistical Summary:")
print(df.describe()) 

# Handling Missing Data using Pandas

import pandas as pd
import numpy as np

# Creating DataFrame with Missing Values
data={

    "Name":["Sakshi","Ragul","Ankit","Piya"],
    "Marks":[95, np.nan,88,np.nan],
    "City":["Chennai","Delhi",np.nan ,"Mumbai"]
}
df=pd.DataFrame(data)

print("Original DataFrame:")
print(df)
# Out:
# Pandas series: 0    10
# 1    20
# 2    30
# 3    40
# 4    50
# dtype: int64
#
# First Element: 10
#
# Series With custom index: math       80
# science    90
# english    95
# dtype: int64
#
# DataFrame:
#     id    name  marks
# 0  101  sakshi     95
# 1  102   rahul     88
# 2  103   ankit     90
#
# First two rows:     id    name  marks
# 0  101  sakshi     95
# 1  102   rahul     88
#
# last two rows:     id   name  marks
# 1  102  rahul     88
# 2  103  ankit     90
#
# column names: Index(['id', 'name', 'marks'], dtype='str')
#
# Second Row using iloc:
# id          101
# name     sakshi
# marks        95
# Name: 0, dtype: object
#
# After Adding Grade column:
#     id    name  marks Grade
# 0  101  sakshi     95     A
# 1  102   rahul     88     B
# 2  103   ankit     90     A
#
# After Updating Marks:
#     id    name  marks Grade  Marks
# 0  101  sakshi     95     A    NaN
# 1  102   rahul     88     B   92.0
# 2  103   ankit     90     A    NaN
#
# After Removing Grade column:
#     id    name  marks  Marks
# 0  101  sakshi     95    NaN
# 1  102   rahul     88   92.0
# 2  103   ankit     90    NaN
#
# DataFrame Information:
# <class 'pandas.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 4 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   id      3 non-null      int64
#  1   name    3 non-null      str
#  2   marks   3 non-null      int64
#  3   Marks   1 non-null      float64
# dtypes: float64(1), int64(2), str(1)
# memory usage: 244.0 bytes
# None
#
# Statistical Summary:
#           id      marks  Marks
# count    3.0   3.000000    1.0
# mean   102.0  91.000000   92.0
# std      1.0   3.605551    NaN
# min    101.0  88.000000   92.0
# 25%    101.5  89.000000   92.0
# 50%    102.0  90.000000   92.0
# 75%    102.5  92.500000   92.0
# max    103.0  95.000000   92.0
# Original DataFrame:
#      Name  Marks     City
# 0  Sakshi   95.0  Chennai
# 1   Ragul    NaN    Delhi
# 2   Ankit   88.0      NaN
# 3    Piya    NaN   Mumbai

# %% [markdown]
# # Practical 13

# %%
# Grouping and Aggregating Data using Pandas 

import pandas as pd

# Creating DataFrame
data={

    "Department":["HR","IT","HR","IT","Sales","Sales"],
    "Employe":["Amit","Ragul","Priya","Ankit","Sakshi","Riya"],
    "Salary":[30000,50000,35000,60000,45000,40000],
    "Experience":[2,5,3,6,4,2]
}
df=pd.DataFrame(data)
print("Orginal Dataframe:")
print(df)

# Grouping by Department
grouped = df.groupby("Department")

# Sum Aggregation
print("\nSum of Salary by Department:")
print(grouped["Salary"].sum())

# Mean Aggregation
print("\nAverage Salary by Department:")
print(grouped["Salary"].mean())

# Maximum Salary
print("\nMaximum Salary by Department:")
print(grouped["Salary"].max())

# Minimum Salary
print("\nMinimum Salary by Department:")
print(grouped["Salary"].min())

# Multiple Aggregations
print("\nMultiple Aggregations:")
print(
    grouped["Salary"].agg(
        ["sum", "mean", "max", "min"]
    )
)

# Grouping Multiple Columns
print("\nGrouping by Department and Experience:")

group_multi = df.groupby(
    ["Department", "Experience"]
)["Salary"].sum()

print(group_multi)

# Iterating Groups
print("\nDisplaying Each Group:")

for name, group in grouped:
    print("\nDepartment:", name)
    print(group)

# Sorting Values
print("\nSorted DataFrame by Salary:")

sorted_df = df.sort_values(by="Salary")
print(sorted_df)
# Out:
# Orginal Dataframe:
#   Department Employe  Salary  Experience
# 0         HR    Amit   30000           2
# 1         IT   Ragul   50000           5
# 2         HR   Priya   35000           3
# 3         IT   Ankit   60000           6
# 4      Sales  Sakshi   45000           4
# 5      Sales    Riya   40000           2
#
# Sum of Salary by Department:
# Department
# HR        65000
# IT       110000
# Sales     85000
# Name: Salary, dtype: int64
#
# Average Salary by Department:
# Department
# HR       32500.0
# IT       55000.0
# Sales    42500.0
# Name: Salary, dtype: float64
#
# Maximum Salary by Department:
# Department
# HR       35000
# IT       60000
# Sales    45000
# Name: Salary, dtype: int64
#
# Minimum Salary by Department:
# Department
# HR       30000
# IT       50000
# Sales    40000
# Name: Salary, dtype: int64
#
# Multiple Aggregations:
#                sum     mean    max    min
# Department
# HR           65000  32500.0  35000  30000
# IT          110000  55000.0  60000  50000
# Sales        85000  42500.0  45000  40000
#
# Grouping by Department and Experience:
# Department  Experience
# HR          2             30000
#             3             35000
# IT          5             50000
#             6             60000
# Sales       2             40000
#             4             45000
# Name: Salary, dtype: int64
#
# Displaying Each Group:
#
# Department: HR
#   Department Employe  Salary  Experience
# 0         HR    Amit   30000           2
# 2         HR   Priya   35000           3
#
# Department: IT
#   Department Employe  Salary  Experience
# 1         IT   Ragul   50000           5
# 3         IT   Ankit   60000           6
#
# Department: Sales
#   Department Employe  Salary  Experience
# 4      Sales  Sakshi   45000           4
# 5      Sales    Riya   40000           2
#
# Sorted DataFrame by Salary:
#   Department Employe  Salary  Experience
# 0         HR    Amit   30000           2
# 2         HR   Priya   35000           3
# 5      Sales    Riya   40000           2
# 4      Sales  Sakshi   45000           4
# 1         IT   Ragul   50000           5
# 3         IT   Ankit   60000           6

# %% [markdown]
# # practical 14

# %%
# Merge and Join DataFrames using Pandas

import pandas as pd

# -------- CONCATENATE OPERATIONS --------
# (all columns name should be same)

# Creating First DataFrame
df1 = pd.DataFrame({
    "ID": [101, 102, 103, 105],
    "Marks": [95, 88, 90, 85]
}, index=[0, 1, 2, 3])

print("\nDataFrame 1:")
print(df1)


# Creating Second DataFrame
df2 = pd.DataFrame({
    "ID": [201, 202, 203, 205],
    "Marks": [85, 78, 80, 65]
}, index=[4, 5, 6, 7])

print("\nDataFrame 2:")
print(df2)

frames=[df1,df2]
result=pd.concat(frames)
print("concatenate dataframe")
print(result)

# ---------------- MERGE OPERATIONS ----------------
# (at least one column should be same, others can be different)

# Creating First DataFrame
df1 = pd.DataFrame({
    "ID": [101, 102, 103, 104],
    "Name": ["Sakshi", "Rahul", "Ankit", "Priya"]
})

print("DataFrame 1:")
print(df1)


# Creating Second DataFrame
df2 = pd.DataFrame({
    "ID": [101, 102, 103, 105],
    "Marks": [95, 88, 90, 85]
}, index=[0, 1, 2, 3])

print("\nDataFrame 2:")
print(df2)

frames = [df1,df2]
result = pd.concat(frames)
print("concatenate dataframes")
print(result)

# ---------------- MERGE OPERATIONS ---------------- ( at least one column should be same, others can be different  )

# Creating First DataFrame
df1 = pd.DataFrame({
    "ID": [101, 102, 103, 104],
    "Name": ["Sakshi", "Rahul", "Ankit", "Priya"]
})

print("DataFrame 1:")
print(df1)

# Creating Second DataFrame
df2 = pd.DataFrame({
    "ID": [101, 102, 103, 105],
    "Marks": [95, 88, 90, 85]
}, index=[0, 1, 2, 3])   

print("\nDataFrame 2:")
print(df2)

# Inner Merge
inner_merge = pd.merge(df1, df2, on="ID", how="inner")

print("\nInner Merge:")
print(inner_merge)

# Left Merge
left_merge = pd.merge(df1, df2, on="ID", how="left")

print("\nLeft Merge:")
print(left_merge)

# Right Merge
right_merge = pd.merge(df1, df2, on="ID", how="right")

print("\nRight Merge:")
print(right_merge)

# Outer Merge
outer_merge = pd.merge(df1, df2, on="ID", how="outer")

print("\nOuter Merge:")
print(outer_merge)

# ---------------- JOIN OPERATIONS ---------------- ( columns names in both datframes is different )

# Creating DataFrames for Join
df3 = pd.DataFrame({
    "Name": ["Abhi", "Yuvash", "Saran"]
}, index=[1, 2, 3])

df4 = pd.DataFrame({
    "Salary": [30000, 40000, 50000]
}, index=[1, 2, 3])

print("\nDataFrame 3:")
print(df3)

print("\nDataFrame 4:")
print(df4)

# Joining DataFrames
joined_df = df3.join(df4)

print("\nJoined DataFrame:")
print(joined_df)

# Joining with Different Join Types
left_join = df3.join(df4, how="left")

print("\nLeft Join:")
print(left_join)

right_join = df3.join(df4, how="right")

print("\nRight Join:")
print(right_join)

outer_join = df3.join(df4, how="outer")

print("\nOuter Join:")
print(outer_join)
# Out:
# DataFrame 1:
#     ID  Marks
# 0  101     95
# 1  102     88
# 2  103     90
# 3  105     85
#
# DataFrame 2:
#     ID  Marks
# 4  201     85
# 5  202     78
# 6  203     80
# 7  205     65
# concatenate dataframe
#     ID  Marks
# 0  101     95
# 1  102     88
# 2  103     90
# 3  105     85
# 4  201     85
# 5  202     78
# 6  203     80
# 7  205     65
# DataFrame 1:
#     ID    Name
# 0  101  Sakshi
# 1  102   Rahul
# 2  103   Ankit
# 3  104   Priya
#
# DataFrame 2:
#     ID  Marks
# 0  101     95
# 1  102     88
# 2  103     90
# 3  105     85
# concatenate dataframes
#     ID    Name  Marks
# 0  101  Sakshi    NaN
# 1  102   Rahul    NaN
# 2  103   Ankit    NaN
# 3  104   Priya    NaN
# 0  101     NaN   95.0
# 1  102     NaN   88.0
# 2  103     NaN   90.0
# 3  105     NaN   85.0
# DataFrame 1:
#     ID    Name
# 0  101  Sakshi
# 1  102   Rahul
# 2  103   Ankit
# 3  104   Priya
#
# DataFrame 2:
#     ID  Marks
# 0  101     95
# 1  102     88
# 2  103     90
# 3  105     85
#
# Inner Merge:
#     ID    Name  Marks
# 0  101  Sakshi     95
# 1  102   Rahul     88
# 2  103   Ankit     90
#
# Left Merge:
#     ID    Name  Marks
# 0  101  Sakshi   95.0
# 1  102   Rahul   88.0
# 2  103   Ankit   90.0
# 3  104   Priya    NaN
#
# Right Merge:
#     ID    Name  Marks
# 0  101  Sakshi     95
# 1  102   Rahul     88
# 2  103   Ankit     90
# 3  105     NaN     85
#
# Outer Merge:
#     ID    Name  Marks
# 0  101  Sakshi   95.0
# 1  102   Rahul   88.0
# 2  103   Ankit   90.0
# 3  104   Priya    NaN
# 4  105     NaN   85.0
#
# DataFrame 3:
#      Name
# 1    Abhi
# 2  Yuvash
# 3   Saran
#
# DataFrame 4:
#    Salary
# 1   30000
# 2   40000
# 3   50000
#
# Joined DataFrame:
#      Name  Salary
# 1    Abhi   30000
# 2  Yuvash   40000
# 3   Saran   50000
#
# Left Join:
#      Name  Salary
# 1    Abhi   30000
# 2  Yuvash   40000
# 3   Saran   50000
#
# Right Join:
#      Name  Salary
# 1    Abhi   30000
# 2  Yuvash   40000
# 3   Saran   50000
#
# Outer Join:
#      Name  Salary
# 1    Abhi   30000
# 2  Yuvash   40000
# 3   Saran   50000

# %% [markdown]
# # practical 15

# %%
# Simple plots using Matplotlib

import matplotlib.pyplot as plt

#------------------LINE PLOT--------------------

x=[1,2,3,4,5]
y=[10,20,3,40,50]

plt.figure(figsize=(5,4))

plt.plot(x,y)

plt.title("Line Plot")
plt.xlabel("X Values")
plt.ylabel("Y Values")

plt.show()

#-------------------BAR GRAPH----------------------
student=["A","B","C","D"]
marks=[85,90,75,88]

plt.figure(figsize=(5,4))

plt.bar(student,marks)

plt.title("Bar Graph")
plt.xlabel("Student")
plt.ylabel("Marks")

plt.show()

#---------------------HISTOGRAM-----------------

data=[10,20,20,30,30,30,40,50,50]

plt.figure(figsize=(5,4))
plt.hist(data,bins=5)

plt.title("Histogram")
plt.xlabel("Values")
plt.ylabel("Frequency")

plt.show()

# %% [markdown]
# # Practical 16

# %%
x = [1, 2, 3, 4, 5]
y = [10, 25 ,30, 45, 50]

plt.figure(figsize=(5,4))

plt.scatter(x,y)

plt.title("Scatter Plot")
plt.xlabel("X Values")
plt.ylabel("Y Values")

plt.show()

#--------------------SUBPLOTS-----------------------------

x1=[1,2,3,4]
y1=[10,20,30,40]

x2=[1,2,3,4]
y2=[40,30,20,10]

plt.figure(figsize=(8,4))

# First Subplot
plt.subplot(1,2,1)

plt.plot(x1,y1)

plt.title("Line Plot")

# Second Subplot
plt.subplot(1,2,2)

plt.bar(x2,y2)

plt.title("Bar Graph")

plt.tight_layout()

plt.show()

# %% [markdown]
# # PRACTICAL 17

# %%
# PRACTICAL 17
# Load and Analyze a CSV Dataset using Pandas

import pandas as pd
import csv

# Loading CSV File
file_path = r"C:\Users\Admin\Desktop\weekly task\students.csv"

# 1. Load the CSV dataset
#df = pd.read_csv(file_path)
df = pd.read_csv(file_path, sep=",", quoting=csv.QUOTE_NONE)

# 2. Display complete dataset
print("========== COMPLETE DATASET ==========")
print(df)

# 3. Display first 5 rows
print("\n========== FIRST 5 ROWS ==========")
print(df.head())

# 4. Display last 5 rows
print("\n========== LAST 5 ROWS ==========")
print(df.tail())

# 5. Display number of rows and columns
print("\n========== DATASET SHAPE ==========")
print(df.shape)

# 6. Display column names
print("\n========== COLUMN NAMES ==========")
print(df.columns)

# 7. Display data types
print("\n========== DATA TYPES ==========")
print(df.dtypes)

# 8. Display dataset information
print("\n========== DATASET INFORMATION ==========")
df.info()

# 9. Display statistical summary
print("\n========== STATISTICAL SUMMARY ==========")
print(df.describe())

# 10. Check missing values
print("\n========== MISSING VALUES ==========")
print(df.isnull().sum())

# 11. Display a specific column
print("\n========== MARKS COLUMN ==========")
print(df["Marks"])

# 12. Filter students with marks greater than 80
print("\n========== STUDENTS WITH MARKS > 80 ==========")
print(df[df["Marks"] > 80])

# 13. Sort dataset by Marks
print("\n========== DATA SORTED BY MARKS ==========")
print(df.sort_values(by="Marks"))

# 14. Calculate average marks by department
print("\n========== AVERAGE MARKS BY DEPARTMENT ==========")
print(df.groupby("Department")["Marks"].mean())
# Out:
# ========== COMPLETE DATASET ==========
#     "ID    Name      Department  Marks       City"
# 0  "101  Sakshi    Data Science     95    Chennai"
# 1  "102   Rahul              AI     88      Delhi"
# 2  "103   Ankit    Data Science     91     Mumbai"
# 3  "104   Priya  Cyber Security     84  Bangalore"
# 4  "105    Riya              AI     90  Hyderabad"
# 5  "106    Amit    Data Science     76       Pune"
# 6  "107    Neha  Cyber Security     82    Kolkata"
# 7  "108   Karan              AI     89    Chennai"
# 8  "109  Simran    Data Science     93      Delhi"
# 9  "110   Arjun  Cyber Security     85     Mumbai"
#
# ========== FIRST 5 ROWS ==========
#     "ID    Name      Department  Marks       City"
# 0  "101  Sakshi    Data Science     95    Chennai"
# 1  "102   Rahul              AI     88      Delhi"
# 2  "103   Ankit    Data Science     91     Mumbai"
# 3  "104   Priya  Cyber Security     84  Bangalore"
# 4  "105    Riya              AI     90  Hyderabad"
#
# ========== LAST 5 ROWS ==========
#     "ID    Name      Department  Marks     City"
# 5  "106    Amit    Data Science     76     Pune"
# 6  "107    Neha  Cyber Security     82  Kolkata"
# 7  "108   Karan              AI     89  Chennai"
# 8  "109  Simran    Data Science     93    Delhi"
# 9  "110   Arjun  Cyber Security     85   Mumbai"
#
# ========== DATASET SHAPE ==========
# (10, 5)
#
# ========== COLUMN NAMES ==========
# Index(['"ID', 'Name', 'Department', 'Marks', 'City"'], dtype='str')
#
# ========== DATA TYPES ==========
# "ID             str
# Name            str
# Department      str
# Marks         int64
# City"           str
# dtype: object
#
# ========== DATASET INFORMATION ==========
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   "ID         10 non-null     str
#  1   Name        10 non-null     str
#  2   Department  10 non-null     str
#  3   Marks       10 non-null     int64
#  4   City"       10 non-null     str
# dtypes: int64(1), str(4)
# memory usage: 792.0 bytes
#
# ========== STATISTICAL SUMMARY ==========
#            Marks
# count  10.000000
# mean   87.300000
# std     5.657836
# min    76.000000
# 25%    84.250000
# 50%    88.500000
# 75%    90.750000
# max    95.000000
#
# ========== MISSING VALUES ==========
# "ID           0
# Name          0
# Department    0
# Marks         0
# City"         0
# dtype: int64
#
# ========== MARKS COLUMN ==========
# 0    95
# 1    88
# 2    91
# 3    84
# 4    90
# 5    76
# 6    82
# 7    89
# 8    93
# 9    85
# Name: Marks, dtype: int64
#
# ========== STUDENTS WITH MARKS > 80 ==========
#     "ID    Name      Department  Marks       City"
# 0  "101  Sakshi    Data Science     95    Chennai"
# 1  "102   Rahul              AI     88      Delhi"
# 2  "103   Ankit    Data Science     91     Mumbai"
# 3  "104   Priya  Cyber Security     84  Bangalore"
# 4  "105    Riya              AI     90  Hyderabad"
# 6  "107    Neha  Cyber Security     82    Kolkata"
# 7  "108   Karan              AI     89    Chennai"
# 8  "109  Simran    Data Science     93      Delhi"
# 9  "110   Arjun  Cyber Security     85     Mumbai"
#
# ========== DATA SORTED BY MARKS ==========
#     "ID    Name      Department  Marks       City"
# 5  "106    Amit    Data Science     76       Pune"
# 6  "107    Neha  Cyber Security     82    Kolkata"
# 3  "104   Priya  Cyber Security     84  Bangalore"
# 9  "110   Arjun  Cyber Security     85     Mumbai"
# 1  "102   Rahul              AI     88      Delhi"
# 7  "108   Karan              AI     89    Chennai"
# 4  "105    Riya              AI     90  Hyderabad"
# 2  "103   Ankit    Data Science     91     Mumbai"
# 8  "109  Simran    Data Science     93      Delhi"
# 0  "101  Sakshi    Data Science     95    Chennai"
#
# ========== AVERAGE MARKS BY DEPARTMENT ==========
# Department
# AI                89.000000
# Cyber Security    83.666667
# Data Science      88.750000
# Name: Marks, dtype: float64

# %% [markdown]
# # Practical 18

# %%
# PRACTICAL 18
# Basic Data Cleaning and Preprocessing

import pandas as pd
import numpy as np

# Loading CSV File


# 1. Load the CSV dataset
#df = pd.read_csv(file_path)
df = pd.read_csv(file_path, sep=",", quoting=csv.QUOTE_NONE)

# 2. Display original dataset
print("========== ORIGINAL DATASET ==========")
print(df)

# 3. Display dataset information
print("\n========== ORIGINAL INFORMATION ==========")
df.info()

# 4. Check missing values
print("\n========== MISSING VALUES ==========")
print(df.isnull().sum())

# 5. Fill missing Age values with mean
if "Age" in df.columns:
    df["Age"] = df["Age"].fillna(df["Age"].mean())

# 6. Fill missing Marks values with mean
if "Marks" in df.columns:
    df["Marks"] = df["Marks"].fillna(df["Marks"].mean())

# 7. Fill missing City values with "Unknown"
if "City" in df.columns:
    df["City"] = df["City"].fillna("Unknown")

# 8. Remove duplicate records
df = df.drop_duplicates()

print("\n========== AFTER REMOVING DUPLICATES ==========")
print(df)

# 9. Remove extra spaces from Name column
if "Name" in df.columns:
    df["Name"] = df["Name"].str.strip()

# 10. Convert Name column to lowercase
if "Name" in df.columns:
    df["Name"] = df["Name"].str.lower()

# 11. Convert City column to lowercase
if "City" in df.columns:
    df["City"] = df["City"].str.lower()

# 12. Convert Age into integer
if "Age" in df.columns:
    df["Age"] = df["Age"].astype(int)

# 13. Rename Marks column as Score
if "Marks" in df.columns:
    df.rename(columns={"Marks": "Score"}, inplace=True)

# 14. Sort dataset by Score
if "Score" in df.columns:
    df = df.sort_values(by="Score", ascending=False)

# 15. Reset the index
df = df.reset_index(drop=True)

# 16. Display cleaned dataset
print("\n========== CLEANED DATASET ==========")
print(df)

# 17. Check missing values after cleaning
print("\n========== MISSING VALUES AFTER CLEANING ==========")
print(df.isnull().sum())

# 18. Display final dataset information
print("\n========== FINAL DATASET INFORMATION ==========")
df.info()
# Out:
# ========== ORIGINAL DATASET ==========
#     "ID    Name      Department  Marks       City"
# 0  "101  Sakshi    Data Science     95    Chennai"
# 1  "102   Rahul              AI     88      Delhi"
# 2  "103   Ankit    Data Science     91     Mumbai"
# 3  "104   Priya  Cyber Security     84  Bangalore"
# 4  "105    Riya              AI     90  Hyderabad"
# 5  "106    Amit    Data Science     76       Pune"
# 6  "107    Neha  Cyber Security     82    Kolkata"
# 7  "108   Karan              AI     89    Chennai"
# 8  "109  Simran    Data Science     93      Delhi"
# 9  "110   Arjun  Cyber Security     85     Mumbai"
#
# ========== ORIGINAL INFORMATION ==========
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   "ID         10 non-null     str
#  1   Name        10 non-null     str
#  2   Department  10 non-null     str
#  3   Marks       10 non-null     int64
#  4   City"       10 non-null     str
# dtypes: int64(1), str(4)
# memory usage: 792.0 bytes
#
# ========== MISSING VALUES ==========
# "ID           0
# Name          0
# Department    0
# Marks         0
# City"         0
# dtype: int64
#
# ========== AFTER REMOVING DUPLICATES ==========
#     "ID    Name      Department  Marks       City"
# 0  "101  Sakshi    Data Science     95    Chennai"
# 1  "102   Rahul              AI     88      Delhi"
# 2  "103   Ankit    Data Science     91     Mumbai"
# 3  "104   Priya  Cyber Security     84  Bangalore"
# 4  "105    Riya              AI     90  Hyderabad"
# 5  "106    Amit    Data Science     76       Pune"
# 6  "107    Neha  Cyber Security     82    Kolkata"
# 7  "108   Karan              AI     89    Chennai"
# 8  "109  Simran    Data Science     93      Delhi"
# 9  "110   Arjun  Cyber Security     85     Mumbai"
#
# ========== CLEANED DATASET ==========
#     "ID    Name      Department  Score       City"
# 0  "101  sakshi    Data Science     95    Chennai"
# 1  "109  simran    Data Science     93      Delhi"
# 2  "103   ankit    Data Science     91     Mumbai"
# 3  "105    riya              AI     90  Hyderabad"
# 4  "108   karan              AI     89    Chennai"
# 5  "102   rahul              AI     88      Delhi"
# 6  "110   arjun  Cyber Security     85     Mumbai"
# 7  "104   priya  Cyber Security     84  Bangalore"
# 8  "107    neha  Cyber Security     82    Kolkata"
# 9  "106    amit    Data Science     76       Pune"
#
# ========== MISSING VALUES AFTER CLEANING ==========
# "ID           0
# Name          0
# Department    0
# Score         0
# City"         0
# dtype: int64
#
# ========== FINAL DATASET INFORMATION ==========
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   "ID         10 non-null     str
#  1   Name        10 non-null     str
#  2   Department  10 non-null     str
#  3   Score       10 non-null     int64
#  4   City"       10 non-null     str
# dtypes: int64(1), str(4)
# memory usage: 800.0 bytes

# %% [markdown]
# # Practical 19

# %%
# PRACTICAL 18
# Basic Data Cleaning and Preprocessing

import pandas as pd
import numpy as np

# Loading CSV File
file_path = r"C:\Users\Admin\Desktop\weekly task\students.csv"


# 1. Load the CSV dataset
#df = pd.read_csv(file_path)
df = pd.read_csv(file_path, sep=",", quoting=csv.QUOTE_NONE)

# 2. Display original dataset
print("========== ORIGINAL DATASET ==========")
print(df)

# 3. Display dataset information
print("\n========== ORIGINAL INFORMATION ==========")
df.info()

# 4. Check missing values
print("\n========== MISSING VALUES ==========")
print(df.isnull().sum())

# 5. Fill missing Age values with mean
if "Age" in df.columns:
    df["Age"] = df["Age"].fillna(df["Age"].mean())

# 6. Fill missing Marks values with mean
if "Marks" in df.columns:
    df["Marks"] = df["Marks"].fillna(df["Marks"].mean())

# 7. Fill missing City values with "Unknown"
if "City" in df.columns:
    df["City"] = df["City"].fillna("Unknown")

# 8. Remove duplicate records
df = df.drop_duplicates()

print("\n========== AFTER REMOVING DUPLICATES ==========")
print(df)

# 9. Remove extra spaces from Name column
if "Name" in df.columns:
    df["Name"] = df["Name"].str.strip()

# 10. Convert Name column to lowercase
if "Name" in df.columns:
    df["Name"] = df["Name"].str.lower()

# 11. Convert City column to lowercase
if "City" in df.columns:
    df["City"] = df["City"].str.lower()

# 12. Convert Age into integer
if "Age" in df.columns:
    df["Age"] = df["Age"].astype(int)

# 13. Rename Marks column as Score
if "Marks" in df.columns:
    df.rename(columns={"Marks": "Score"}, inplace=True)

# 14. Sort dataset by Score
if "Score" in df.columns:
    df = df.sort_values(by="Score", ascending=False)

# 15. Reset the index
df = df.reset_index(drop=True)

# 16. Display cleaned dataset
print("\n========== CLEANED DATASET ==========")
print(df)

# 17. Check missing values after cleaning
print("\n========== MISSING VALUES AFTER CLEANING ==========")
print(df.isnull().sum())

# 18. Display final dataset information
print("\n========== FINAL DATASET INFORMATION ==========")
df.info()
# Out:
# ========== ORIGINAL DATASET ==========
#     "ID    Name      Department  Marks       City"
# 0  "101  Sakshi    Data Science     95    Chennai"
# 1  "102   Rahul              AI     88      Delhi"
# 2  "103   Ankit    Data Science     91     Mumbai"
# 3  "104   Priya  Cyber Security     84  Bangalore"
# 4  "105    Riya              AI     90  Hyderabad"
# 5  "106    Amit    Data Science     76       Pune"
# 6  "107    Neha  Cyber Security     82    Kolkata"
# 7  "108   Karan              AI     89    Chennai"
# 8  "109  Simran    Data Science     93      Delhi"
# 9  "110   Arjun  Cyber Security     85     Mumbai"
#
# ========== ORIGINAL INFORMATION ==========
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   "ID         10 non-null     str
#  1   Name        10 non-null     str
#  2   Department  10 non-null     str
#  3   Marks       10 non-null     int64
#  4   City"       10 non-null     str
# dtypes: int64(1), str(4)
# memory usage: 792.0 bytes
#
# ========== MISSING VALUES ==========
# "ID           0
# Name          0
# Department    0
# Marks         0
# City"         0
# dtype: int64
#
# ========== AFTER REMOVING DUPLICATES ==========
#     "ID    Name      Department  Marks       City"
# 0  "101  Sakshi    Data Science     95    Chennai"
# 1  "102   Rahul              AI     88      Delhi"
# 2  "103   Ankit    Data Science     91     Mumbai"
# 3  "104   Priya  Cyber Security     84  Bangalore"
# 4  "105    Riya              AI     90  Hyderabad"
# 5  "106    Amit    Data Science     76       Pune"
# 6  "107    Neha  Cyber Security     82    Kolkata"
# 7  "108   Karan              AI     89    Chennai"
# 8  "109  Simran    Data Science     93      Delhi"
# 9  "110   Arjun  Cyber Security     85     Mumbai"
#
# ========== CLEANED DATASET ==========
#     "ID    Name      Department  Score       City"
# 0  "101  sakshi    Data Science     95    Chennai"
# 1  "109  simran    Data Science     93      Delhi"
# 2  "103   ankit    Data Science     91     Mumbai"
# 3  "105    riya              AI     90  Hyderabad"
# 4  "108   karan              AI     89    Chennai"
# 5  "102   rahul              AI     88      Delhi"
# 6  "110   arjun  Cyber Security     85     Mumbai"
# 7  "104   priya  Cyber Security     84  Bangalore"
# 8  "107    neha  Cyber Security     82    Kolkata"
# 9  "106    amit    Data Science     76       Pune"
#
# ========== MISSING VALUES AFTER CLEANING ==========
# "ID           0
# Name          0
# Department    0
# Score         0
# City"         0
# dtype: int64
#
# ========== FINAL DATASET INFORMATION ==========
# <class 'pandas.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   "ID         10 non-null     str
#  1   Name        10 non-null     str
#  2   Department  10 non-null     str
#  3   Score       10 non-null     int64
#  4   City"       10 non-null     str
# dtypes: int64(1), str(4)
# memory usage: 800.0 bytes

# %% [markdown]
# # Practical 20

# %%
# Data Visualization using Seaborn
import pandas as pd 
import seaborn as sns
import matplotlib.pyplot as plt

# Creating Sanple dataset 
data = {
    "Maths"   : [85, 90, 78, 92, 88],
    "Science" : [80, 85, 75, 95, 89],
    "English" : [78, 88, 72, 90, 84]
}

# Creating Dataframe
df= pd.DataFrame(data)
print("Dataset :")
print(df)
#-------------HEATMAP-----------------------
plt.figure(figsize=(5,4))
sns.heatmap(df, annot=True)
plt.title("heatmap")
plt.show()

#----------------BOXPLOT------------------------

plt.figure(figsize=(5,4))
sns.boxplot(data=df)
plt.title("Boxplot")
plt.show()
#-------------PAIR PLOT---------------------------
sns.pairplot(df)
plt.show()
# Out:
# Dataset :
#    Maths  Science  English
# 0     85       80       78
# 1     90       85       88
# 2     78       75       72
# 3     92       95       90
# 4     88       89       84
